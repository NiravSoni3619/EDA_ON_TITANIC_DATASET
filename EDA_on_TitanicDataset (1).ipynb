# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train (1).csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %% [markdown]
# Categorical Columns
#
# 1 Survived
# 2 Pclass
# 3 Sex
# 4 SibSp
# 5 Embarked

# %% [markdown]
# Numerical Columns
#
# 1 passengerid
# 2 age
# 3 fair

# %% [markdown]
# mixed columns
#
# 1 name
# 2 ticket
# 3 cabin

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # basic Conclusion
#
# 1 missing values in age , cabin , embarked
# 2 Most of the data in cabin column is missing
# 3 inappropriate datatypes

# %%
# dropped cabin column due to more numbers of missing values 

df.drop(columns= ['Cabin'] , inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# replacing missing values in Age with mean of the age column 

df['Age'].fillna(df['Age'].mean(), inplace = True)
# Out:
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\2711035970.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace = True)

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# replacing missing values in Embarked with S 
df['Embarked'].fillna('S', inplace = True)
# Out:
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\227553003.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('S', inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Embarked'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')
df['Sex'] = df['Sex'].astype('category')
df['SibSp'] = df['SibSp'].astype('category')
df['Parch'] = df['Parch'].astype('category')
df['Age'] = df['Age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    category
#  7   Parch        891 non-null    category
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: category(5), float64(1), int64(2), object(3)
# memory usage: 47.3+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age        Fare
# count   891.000000  891.000000  891.000000
# mean    446.000000   29.544332   32.204208
# std     257.353842   13.013778   49.693429
# min       1.000000    0.000000    0.000000
# 25%     223.500000   22.000000    7.910400
# 50%     446.000000   29.000000   14.454200
# 75%     668.500000   35.000000   31.000000
# max     891.000000   80.000000  512.329200

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
sns.countplot(x='Survived',data = df ,  palette=['Red', 'Green'])
death_percent = (df['Survived'].value_counts().values[0]/891)*100
print("Out of 891 people {} percent people died".format(death_percent))
# Out:
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\3305074261.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived',data = df ,  palette=['Red', 'Green'])
# Out of 891 people 61.61616161616161 percent people died

# %%
print((df['Pclass'].value_counts()/891)*100)
sns.countplot(x = 'Pclass' , data = df , palette = ['red', 'yellow' , 'green'] )
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: count, dtype: float64
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\3787342391.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Pclass' , data = df , palette = ['red', 'yellow' , 'green'] )
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
print((df['Sex'].value_counts()/891)*100)
sns.countplot(x = 'Sex' , data = df , palette = ['pink' ,'blue'])
# Out:
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\255027228.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Sex' , data = df , palette = ['pink' ,'blue'])
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64
# <Axes: xlabel='Sex', ylabel='count'>

# %%
print((df['SibSp'].value_counts()/891)*100)
sns.countplot(x = 'SibSp' , data = df)
# Out:
# SibSp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: count, dtype: float64
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
print((df['Parch'].value_counts()/891)*100)
sns.countplot(x = 'Parch' , data = df)
# Out:
# Parch
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 3     0.561167
# 5     0.561167
# 4     0.448934
# 6     0.112233
# Name: count, dtype: float64
# <Axes: xlabel='Parch', ylabel='count'>

# %%
print((df['Embarked'].value_counts()/891)*100)
sns.countplot(x = 'Embarked' , data = df)
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: count, dtype: float64
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.distplot(df['Age'])
print(df['Age'].skew())
print(df['Age'].kurt())
# Out:
# 0.45956263424701577
# 0.9865867453652877
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\350049838.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
sns.boxplot(x = 'Age' , data = df)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Fare'])
print(df['Fare'].skew())

print(df['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\3026519889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Fare'])

# %%
sns.boxplot(x= 'Fare' , data = df)
# Out:
# <Axes: xlabel='Fare'>

# %%
print("people with fare  in between 200 to 300 are" , df[ (df['Fare'] > 200) & (df['Fare']<300)] .shape[0])
print("people with fare  in between 200 to 300 are" , df[ df['Fare']>300 ].shape[0])
# Out:
# people with fare  in between 200 to 300 are 17
# people with fare  in between 200 to 300 are 3

# %% [markdown]
# # Multivariate Analysis

# %%
ax = sns.countplot(x='Survived', hue='Pclass', data=df)

# Annotate each bar with the count
for p in ax.patches:
    height = p.get_height(
        
    )
    ax.annotate(f'{height:.0f}', (p.get_x() + p.get_width() / 2., height), 
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

# %%
# survival with sex 
sns.countplot(x = 'Sex' , hue = 'Survived' , data = df)
crosstab = pd.crosstab(df['Sex'], df['Survived']).apply(lambda r : round((r/r.sum())*100,1), axis = 1)
print(crosstab)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
# Survival vs embarked 
sns.countplot(x = 'Survived' , hue = 'Embarked' , data = df)
crosstab = pd.crosstab(df['Embarked'], df['Survived']).apply(lambda r : round((r/r.sum())*100,1), axis = 1)
print(crosstab)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
# Survived vs Age 
plt.figure(figsize = (15,6))
sns.distplot(df[df['Survived']== 0]['Age'])
sns.distplot(df[df['Survived']== 1]['Age'])
# Out:
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\2046316675.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']== 0]['Age'])
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\2046316675.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# survived vs Fare
plt.figure(figsize = (15,6))
sns.distplot(df[df['Survived']== 0]['Fare'])
sns.distplot(df[df['Survived']== 1]['Fare'])
# Out:
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\3640000838.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']== 0]['Fare'])
# C:\Users\Paradox\AppData\Local\Temp\ipykernel_5488\3640000838.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.pairplot(df)

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
correlation_matrix = numeric_cols.corr()

# Plotting heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
# create new column family size 
df['Parch'] = df['Parch'].astype(int)
df['SibSp'] = df['SibSp'].astype(int)
df['Family Size' ] = df['Parch'] + df['SibSp']

# %%
def family_type(number):
    if number == 0 :
        return "Alone"
    elif number >= 1 & number <=4 :
        return "medium"
    return "Large"

df['Family_type'] = df['Family Size'].apply(family_type)
df.sample(5)
# Out:
#      PassengerId Survived Pclass                        Name     Sex  Age  \
# 115          116        0      3       Pekoniemi, Mr. Edvard    male   21
# 264          265        0      3          Henry, Miss. Delia  female   29
# 16            17        0      3        Rice, Master. Eugene    male    2
# 456          457        0      1   Millet, Mr. Francis Davis    male   65
# 374          375        0      3  Palsson, Miss. Stina Viola  female    3
#
#      SibSp  Parch             Ticket    Fare Embarked  Family Size Family_type
# 115      0      0  STON/O 2. 3101294   7.925        S            0       Alone
# 264      0      0             382649   7.750        Q            0       Alone
# 16       4      1             382652  29.125        Q            5      medium
# 456      0      0              13509  26.550        S            0       Alone
# 374      3      1             349909  21.075        S            4      medium

# %%
df.drop( columns = ['SibSp' , 'Parch' , 'Family Size'], inplace= True)

# %%
crosstab = pd.crosstab(df['Family_type'], df['Survived']).apply(lambda r : round((r/r.sum())*100, 1), axis = 1)
print(crosstab)
sns.countplot(x = 'Family_type' , hue = 'Survived' , data = df )
# Out:
# Survived        0     1
# Family_type
# Alone        72.8  27.2
# medium       53.3  46.7
# <Axes: xlabel='Family_type', ylabel='count'>

# %%
# Removing outliers in Age , As it is in normal distribution so using formula mean - 3SD to mean + 3SD
# Calculate mean and standard deviation
mean_age = df['Age'].mean()
std_age = df['Age'].std()

# Define bounds for acceptable values (e.g., within 3 standard deviations)
lower_bound = mean_age - 3 * std_age
upper_bound = mean_age + 3 * std_age

# Filter out outliers
df_no_outliers = df[(df['Age'] >= lower_bound) & (df['Age'] <= upper_bound)]

df = df_no_outliers
df.shape
# Out:
# (884, 10)

# %%
# removing outliers in Fare
# Calculate Q1, Q3, and IQR
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1

# Define lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['Fare'] > lower_bound) & (df['Fare']<upper_bound)]

df.shape
# Out:
# (769, 10)

# %%
# one hot encoding 
df = pd.get_dummies(df, columns=['Sex', 'Embarked', 'Pclass', 'Family_type'], drop_first=True, dtype=int)
df.sample(5)
# Out:
#      PassengerId Survived                             Name  Age    Ticket  \
# 592          593        0       Elsbury, Mr. William James   47  A/5 3902
# 247          248        1  Hamalainen, Mrs. William (Anna)   24    250649
# 7              8        0   Palsson, Master. Gosta Leonard    2    349909
# 673          674        1            Wilhelms, Mr. Charles   31    244270
# 734          735        0     Troupiansky, Mr. Moses Aaron   23    233639
#
#        Fare  Sex_male  Embarked_Q  Embarked_S  Pclass_2  Pclass_3  \
# 592   7.250         1           0           1         0         1
# 247  14.500         0           0           1         1         0
# 7    21.075         1           0           1         0         1
# 673  13.000         1           0           1         1         0
# 734  13.000         1           0           1         1         0
#
#      Family_type_medium
# 592                   0
# 247                   1
# 7                     1
# ...

# %%
columns = ['PassengerId' , 'Age' ,'Fare','Sex_male','Embarked_Q','Embarked_S','Pclass_2','Pclass_3','Family_type_medium']
sns.heatmap(df[columns].corr())
# Out:
# <Axes: >

# %% [markdown]
# # Conclusions
#
# 1 chances of female survival is higher than male survival.
# 2 travelling in Pclass 3 was deadliest.
# 3 people going to c place survived more.
# 4 people in range 20 to 40 had a higher chance of not surviving.
# 5 people travelling with small family had higher chance of surviving than alone and larger families.
